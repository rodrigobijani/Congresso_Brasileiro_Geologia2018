# %% [markdown]
#   <img src='Image/CBG18.png' width="230px" align="right"> <img src='Image/logoON.jpg' width="250px" align="left">

# %% [markdown]
# <center> Dado sintético <center>

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------

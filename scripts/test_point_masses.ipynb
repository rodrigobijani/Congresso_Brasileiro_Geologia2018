# %% [markdown]
# # Objetivo: criar a função que plota pontos de massa no espaço 3D:

# %%
# Importanto bibliotecas necessárias para utilização das funções específicas do python:
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pylab as py
from modules.plots import points3D
# %matplotlib inline

# %%
x = np.linspace(0.0,10.0,100)
y = np.linspace(0.0,10.0,100)
z = np.linspace(-10.0,0.0,100)

# %%
points3D(x, y, z, 30, 45 , 'x', 'y', 'z')
